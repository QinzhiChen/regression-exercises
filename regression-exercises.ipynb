# %%
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

from env import user, password, host
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import env
import os
import csv
import wrangle_zillow
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1038959 entries, 10057 to 843328
# Data columns (total 7 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   bedroom    1038959 non-null  float64
#  1   bathroom   1038959 non-null  float64
#  2   sqtft      1038959 non-null  float64
#  3   taxvalue   1038959 non-null  float64
#  4   yearbuilt  1038476 non-null  object
#  5   taxamount  1038959 non-null  float64
#  6   fips       1038959 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 63.4+ MB

# %%
zillow_train,zillow_validate,zillow_test=wrangle_zillow.wrangle_zillow(1.5)
